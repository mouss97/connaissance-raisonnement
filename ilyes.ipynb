# %%
# ! pip install sparqlwrapper
import pandas as pd
import numpy as np
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

# %%
# Q19317 : FIFA World Cup
# P3450 : sports season of league or competition
# P17 : country
# P1132 : number of participants
# P1346 : winner
# P3279 : statistical leader | meilleur buteur

sparql.setQuery("""
SELECT ?item ?itemLabel ?country ?countryLabel ?participants ?participantsLabel ?winner ?winnerLabel ?leader ?leaderLabel

WHERE {
  # ?item wdt:P3450 wd:Q19317;
      wdt:P17 ?country.
  # ?item wdt:P3450 wd:Q19317;
      wdt:P1132 ?participants.
  # ?item wdt:P3450 wd:Q19317;
      wdt:P1346 ?winner.
  # ?item wdt:P3450 wd:Q19317;
      wdt:P3279 ?leader.

  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
# sparql.setQuery("""

# SELECT ?item ?itemLabel ?mascot ?mascotLabel

# WHERE {
#   ?item wdt:P3450 wd:Q19317;
#       wdt:P822 ?mascot.

#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en".
# }

# """)

# sparql.setReturnFormat(JSON)
# mascots = sparql.query().convert()

# mascots_df = pd.io.json.json_normalize(mascots['results']['bindings'])
# mascots

# %%
results
# Out:
# {'head': {'vars': ['item',
#    'itemLabel',
#    'country',
#    'countryLabel',
#    'participants',
#    'participantsLabel',
#    'winner',
#    'winnerLabel',
#    'leader',
#    'leaderLabel']},
#  'results': {'bindings': [{'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q37285'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q80471'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q676899'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q183'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2006 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Germany'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Italy national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Miroslav Klose'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q46934'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q178628'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q676899'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '24'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q96'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1982 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mexico'},
#     'participantsLabel': {'type': 'literal', 'value': '24'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Italy national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Paolo Rossi'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q46938'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q47778'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q79800'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '24'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q96'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1986 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mexico'},
#     'participantsLabel': {'type': 'literal', 'value': '24'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Argentina national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Gary Lineker'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q46943'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q180649'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q79800'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q414'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1978 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Argentina'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Argentina national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Mario Kempes'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q47735'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q216312'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '33'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q17'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2002 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Japan'},
#     'participantsLabel': {'type': 'literal', 'value': '33'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'José Luis Chilavert'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q47735'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q216312'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '33'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q884'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2002 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South Korea'},
#     'participantsLabel': {'type': 'literal', 'value': '33'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'José Luis Chilavert'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q48432'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q309645'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q134916'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '13'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q77'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1930 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Uruguay'},
#     'participantsLabel': {'type': 'literal', 'value': '13'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Uruguay national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Guillermo Stábile'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q79859'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43666'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43310'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q155'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2014 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Brazil'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Germany national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Thomas Müller'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q101730'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q189217'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q47774'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q142'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1998 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'France'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'France national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Davor Šuker'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q101751'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q187125'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '24'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1994 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'United States of America'},
#     'participantsLabel': {'type': 'literal', 'value': '24'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Hristo Stoichkov'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q101751'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q295746'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '24'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1994 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'United States of America'},
#     'participantsLabel': {'type': 'literal', 'value': '24'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Oleg Salenko'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q131075'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q295265'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43310'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q39'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1954 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Switzerland'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Germany national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Sándor Kocsis'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q131591'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q311739'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q676899'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '15'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q142'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1938 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'France'},
#     'participantsLabel': {'type': 'literal', 'value': '15'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Italy national association football team'},
#     'leaderLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Leônidas'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q132515'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q332012'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q134916'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '13'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q155'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1950 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Brazil'},
#     'participantsLabel': {'type': 'literal', 'value': '13'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Uruguay national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ademir de Menezes'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q132529'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q295307'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43310'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '24'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q38'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1990 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italy'},
#     'participantsLabel': {'type': 'literal', 'value': '24'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Germany national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Salvatore Schillaci'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q132533'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q192749'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q34'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1958 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sweden'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Just Fontaine'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q132664'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43744'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q96'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1970 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mexico'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Gerd Müller'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q134202'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q162043'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q47762'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q145'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1966 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'United Kingdom'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'England national association football team'},
#     'leaderLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Eusébio'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q160813'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q180642'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q298'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1962 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chile'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Garrincha'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q160813'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q201534'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q298'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1962 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chile'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Flórián Albert'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q160813'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q311445'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q298'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1962 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chile'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'},
#     'leaderLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Vavá'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q160813'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q313309'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q298'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1962 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chile'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Valentin Ivanov'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q160813'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q314630'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q298'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1962 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chile'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Leonel Sánchez'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q160813'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q314764'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q298'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1962 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chile'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Dražan Jerković'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q166121'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q271557'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43310'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q183'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1974 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Germany'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Germany national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Grzegorz Lato'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q170645'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q969725'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q47774'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q159'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2018 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Russia'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'France national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Harry Kane'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q176883'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43666'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q42267'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q258'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2010 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South Africa'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Spain national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Thomas Müller'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q176883'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83006'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q42267'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q258'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2010 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South Africa'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Spain national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'David Villa'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q176883'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q124086'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q42267'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q258'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2010 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South Africa'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Spain national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Wesley Sneijder'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q176883'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q261534'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q42267'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q258'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2010 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South Africa'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Spain national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Diego Forlán'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q284163'},
#     'leader': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q615'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q79800'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q846'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2022 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qatar'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Argentina national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Lionel Messi'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q284163'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3275904'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q79800'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q846'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2022 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qatar'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Argentina national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Emiliano Martínez'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q284163'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q21621995'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q79800'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q846'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2022 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qatar'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Argentina national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Kylian Mbappé'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q284163'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q96105248'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q79800'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q846'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2022 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qatar'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Argentina national football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Enzo Fernández'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1477177'},
#     'leader': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q266489'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q676899'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q38'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1934 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italy'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Italy national association football team'},
#     'leaderLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Oldřich Nejedlý'}}]}}

# %%
results_df = pd.io.json.json_normalize(results['results']['bindings'])
results_df.iloc[1]
# Out:
# C:\Users\ilyes\AppData\Local\Temp\ipykernel_11408\3541426254.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   results_df = pd.io.json.json_normalize(results['results']['bindings'])
# item.type                                                       uri
# item.value                    http://www.wikidata.org/entity/Q46934
# leader.type                                                     uri
# leader.value                 http://www.wikidata.org/entity/Q178628
# winner.type                                                     uri
# winner.value                 http://www.wikidata.org/entity/Q676899
# participants.datatype      http://www.w3.org/2001/XMLSchema#decimal
# participants.type                                           literal
# participants.value                                               24
# country.type                                                    uri
# country.value                    http://www.wikidata.org/entity/Q96
# itemLabel.xml:lang                                               en
# itemLabel.type                                              literal
# itemLabel.value                                 1982 FIFA World Cup
# countryLabel.xml:lang                                            en
# countryLabel.type                                           literal
# countryLabel.value                                           Mexico
# participantsLabel.type                                      literal
# participantsLabel.value                                          24
# winnerLabel.xml:lang                                             en
# winnerLabel.type                                            literal
# winnerLabel.value          Italy national association football team
# leaderLabel.xml:lang                                             en
# leaderLabel.type                                            literal
# leaderLabel.value                                       Paolo Rossi
# Name: 1, dtype: object

# %%
results_df= results_df[['item.value', 'itemLabel.value', 'winnerLabel.value',\
            'participantsLabel.value', 'countryLabel.value', 'leaderLabel.value']].sort_values(by = "itemLabel.value")
results_df
# Out:
#                                  item.value      itemLabel.value  \
# 6     http://www.wikidata.org/entity/Q48432  1930 FIFA World Cup
# 34  http://www.wikidata.org/entity/Q1477177  1934 FIFA World Cup
# 12   http://www.wikidata.org/entity/Q131591  1938 FIFA World Cup
# 13   http://www.wikidata.org/entity/Q132515  1950 FIFA World Cup
# 11   http://www.wikidata.org/entity/Q131075  1954 FIFA World Cup
# 15   http://www.wikidata.org/entity/Q132533  1958 FIFA World Cup
# 23   http://www.wikidata.org/entity/Q160813  1962 FIFA World Cup
# 22   http://www.wikidata.org/entity/Q160813  1962 FIFA World Cup
# 21   http://www.wikidata.org/entity/Q160813  1962 FIFA World Cup
# 20   http://www.wikidata.org/entity/Q160813  1962 FIFA World Cup
# 19   http://www.wikidata.org/entity/Q160813  1962 FIFA World Cup
# 18   http://www.wikidata.org/entity/Q160813  1962 FIFA World Cup
# 17   http://www.wikidata.org/entity/Q134202  1966 FIFA World Cup
# 16   http://www.wikidata.org/entity/Q132664  1970 FIFA World Cup
# 24   http://www.wikidata.org/entity/Q166121  1974 FIFA World Cup
# 3     http://www.wikidata.org/entity/Q46943  1978 FIFA World Cup
# 1     http://www.wikidata.org/entity/Q46934  1982 FIFA World Cup
# 2     http://www.wikidata.org/entity/Q46938  1986 FIFA World Cup
# 14   http://www.wikidata.org/entity/Q132529  1990 FIFA World Cup
# 10   http://www.wikidata.org/entity/Q101751  1994 FIFA World Cup
# 9    http://www.wikidata.org/entity/Q101751  1994 FIFA World Cup
# 8    http://www.wikidata.org/entity/Q101730  1998 FIFA World Cup
# 5     http://www.wikidata.org/entity/Q47735  2002 FIFA World Cup
# 4     http://www.wikidata.org/entity/Q47735  2002 FIFA World Cup
# 0     http://www.wikidata.org/entity/Q37285  2006 FIFA World Cup
# 26   http://www.wikidata.org/entity/Q176883  2010 FIFA World Cup
# 27   http://www.wikidata.org/entity/Q176883  2010 FIFA World Cup
# 28   http://www.wikidata.org/entity/Q176883  2010 FIFA World Cup
# 29   http://www.wikidata.org/entity/Q176883  2010 FIFA World Cup
# 7     http://www.wikidata.org/entity/Q79859  2014 FIFA World Cup
# 25   http://www.wikidata.org/entity/Q170645  2018 FIFA World Cup
# 33   http://www.wikidata.org/entity/Q284163  2022 FIFA World Cup
# 30   http://www.wikidata.org/entity/Q284163  2022 FIFA World Cup
# 31   http://www.wikidata.org/entity/Q284163  2022 FIFA World Cup
# 32   http://www.wikidata.org/entity/Q284163  2022 FIFA World Cup
#
#                              winnerLabel.value participantsLabel.value  \
# 6               Uruguay national football team                      13
# 34    Italy national association football team                      16
# 12    Italy national association football team                      15
# 13              Uruguay national football team                      13
# 11  Germany national association football team                      16
# 15               Brazil national football team                      16
# 23               Brazil national football team                      16
# 22               Brazil national football team                      16
# 21               Brazil national football team                      16
# 20               Brazil national football team                      16
# 19               Brazil national football team                      16
# 18               Brazil national football team                      16
# 17  England national association football team                      16
# 16               Brazil national football team                      16
# 24  Germany national association football team                      16
# 3             Argentina national football team                      16
# 1     Italy national association football team                      24
# 2             Argentina national football team                      24
# 14  Germany national association football team                      24
# 10               Brazil national football team                      24
# 9                Brazil national football team                      24
# 8    France national association football team                      32
# 5                Brazil national football team                      33
# 4                Brazil national football team                      33
# 0     Italy national association football team                      32
# 26    Spain national association football team                      32
# 27    Spain national association football team                      32
# 28    Spain national association football team                      32
# 29    Spain national association football team                      32
# 7   Germany national association football team                      32
# 25   France national association football team                      32
# 33            Argentina national football team                      32
# 30            Argentina national football team                      32
# 31            Argentina national football team                      32
# 32            Argentina national football team                      32
#
#           countryLabel.value    leaderLabel.value
# 6                    Uruguay    Guillermo Stábile
# 34                     Italy      Oldřich Nejedlý
# 12                    France             Leônidas
# 13                    Brazil    Ademir de Menezes
# 11               Switzerland        Sándor Kocsis
# 15                    Sweden        Just Fontaine
# 23                     Chile      Dražan Jerković
# 22                     Chile       Leonel Sánchez
# 21                     Chile      Valentin Ivanov
# 20                     Chile                 Vavá
# 19                     Chile       Flórián Albert
# 18                     Chile            Garrincha
# 17            United Kingdom              Eusébio
# 16                    Mexico          Gerd Müller
# 24                   Germany        Grzegorz Lato
# 3                  Argentina         Mario Kempes
# 1                     Mexico          Paolo Rossi
# 2                     Mexico         Gary Lineker
# 14                     Italy  Salvatore Schillaci
# 10  United States of America         Oleg Salenko
# 9   United States of America     Hristo Stoichkov
# 8                     France          Davor Šuker
# 5                South Korea  José Luis Chilavert
# 4                      Japan  José Luis Chilavert
# 0                    Germany       Miroslav Klose
# 26              South Africa        Thomas Müller
# 27              South Africa          David Villa
# 28              South Africa      Wesley Sneijder
# 29              South Africa         Diego Forlán
# 7                     Brazil        Thomas Müller
# 25                    Russia           Harry Kane
# 33                     Qatar       Enzo Fernández
# 30                     Qatar         Lionel Messi
# 31                     Qatar    Emiliano Martínez
# 32                     Qatar        Kylian Mbappé

# %% [markdown]
# # Post processing

# %%
# Change the teams name to keep the country name only
results_df['winnerLabel.value'] = [x.split(' ')[0] for x in results_df['winnerLabel.value']]

# 2002 in both South Korea and Japan
results_df = results_df[results_df['itemLabel.value'] != '2002 FIFA World Cup']
results_df = results_df.append({'item.value': 'http://www.wikidata.org/entity/Q19317', 'itemLabel.value': '2002 FIFA World Cup',
'winnerLabel.value': 'Brazil', 'participantsLabel.value': '32',
'countryLabel.value': 'South Korea & Japan',
'leaderLabel.value': 'Ronaldo'}, ignore_index=True)

# leaderLabel.value : cast to string
results_df['leaderLabel.value'] = results_df['leaderLabel.value'].astype(str)
# concatenate the leaders for each year
results_df = results_df.groupby(
    ['item.value', 'itemLabel.value', 'winnerLabel.value', 'participantsLabel.value', 'countryLabel.value']
        ).agg({'leaderLabel.value': ', '.join}).reset_index()
# keep an only leader for each year
results_df.loc[results_df['itemLabel.value'] == '1962 FIFA World Cup', 'leaderLabel.value'] = 'Garrincha'
results_df.loc[results_df['itemLabel.value'] == '1994 FIFA World Cup', 'leaderLabel.value'] = 'Oleg Salenko'
results_df.loc[results_df['itemLabel.value'] == '2010 FIFA World Cup', 'leaderLabel.value'] = 'Thomas Müller'
results_df.loc[results_df['itemLabel.value'] == '2022 FIFA World Cup', 'leaderLabel.value'] = 'Kylian Mbappé'

# reset the index correctly
results_df.sort_values(by = "itemLabel.value", inplace = True)
results_df = results_df.reset_index(drop=True)

results_df
# Out:
# C:\Users\ilyes\AppData\Local\Temp\ipykernel_11408\1756224227.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'item.value': 'http://www.wikidata.org/entity/Q19317', 'itemLabel.value': '2002 FIFA World Cup',
#                                  item.value      itemLabel.value  \
# 0     http://www.wikidata.org/entity/Q48432  1930 FIFA World Cup
# 1   http://www.wikidata.org/entity/Q1477177  1934 FIFA World Cup
# 2    http://www.wikidata.org/entity/Q131591  1938 FIFA World Cup
# 3    http://www.wikidata.org/entity/Q132515  1950 FIFA World Cup
# 4    http://www.wikidata.org/entity/Q131075  1954 FIFA World Cup
# 5    http://www.wikidata.org/entity/Q132533  1958 FIFA World Cup
# 6    http://www.wikidata.org/entity/Q160813  1962 FIFA World Cup
# 7    http://www.wikidata.org/entity/Q134202  1966 FIFA World Cup
# 8    http://www.wikidata.org/entity/Q132664  1970 FIFA World Cup
# 9    http://www.wikidata.org/entity/Q166121  1974 FIFA World Cup
# 10    http://www.wikidata.org/entity/Q46943  1978 FIFA World Cup
# 11    http://www.wikidata.org/entity/Q46934  1982 FIFA World Cup
# 12    http://www.wikidata.org/entity/Q46938  1986 FIFA World Cup
# 13   http://www.wikidata.org/entity/Q132529  1990 FIFA World Cup
# 14   http://www.wikidata.org/entity/Q101751  1994 FIFA World Cup
# 15   http://www.wikidata.org/entity/Q101730  1998 FIFA World Cup
# 16    http://www.wikidata.org/entity/Q19317  2002 FIFA World Cup
# 17    http://www.wikidata.org/entity/Q37285  2006 FIFA World Cup
# 18   http://www.wikidata.org/entity/Q176883  2010 FIFA World Cup
# 19    http://www.wikidata.org/entity/Q79859  2014 FIFA World Cup
# 20   http://www.wikidata.org/entity/Q170645  2018 FIFA World Cup
# 21   http://www.wikidata.org/entity/Q284163  2022 FIFA World Cup
#
#    winnerLabel.value participantsLabel.value        countryLabel.value  \
# 0            Uruguay                      13                   Uruguay
# 1              Italy                      16                     Italy
# 2              Italy                      15                    France
# 3            Uruguay                      13                    Brazil
# 4            Germany                      16               Switzerland
# 5             Brazil                      16                    Sweden
# 6             Brazil                      16                     Chile
# 7            England                      16            United Kingdom
# 8             Brazil                      16                    Mexico
# 9            Germany                      16                   Germany
# 10         Argentina                      16                 Argentina
# 11             Italy                      24                    Mexico
# 12         Argentina                      24                    Mexico
# 13           Germany                      24                     Italy
# 14            Brazil                      24  United States of America
# 15            France                      32                    France
# 16            Brazil                      32       South Korea & Japan
# 17             Italy                      32                   Germany
# 18             Spain                      32              South Africa
# 19           Germany                      32                    Brazil
# 20            France                      32                    Russia
# 21         Argentina                      32                     Qatar
#
#       leaderLabel.value
# 0     Guillermo Stábile
# 1       Oldřich Nejedlý
# 2              Leônidas
# 3     Ademir de Menezes
# 4         Sándor Kocsis
# 5         Just Fontaine
# 6             Garrincha
# 7               Eusébio
# 8           Gerd Müller
# 9         Grzegorz Lato
# 10         Mario Kempes
# 11          Paolo Rossi
# 12         Gary Lineker
# 13  Salvatore Schillaci
# 14         Oleg Salenko
# 15          Davor Šuker
# 16              Ronaldo
# 17       Miroslav Klose
# 18        Thomas Müller
# 19        Thomas Müller
# 20           Harry Kane
# 21        Kylian Mbappé

# %% [markdown]
# # Create Quiz Bank

# %%
import random
def quiz_bank(df):
    quiz_bank = {}
    for ind,val in df.iterrows(): #['itemLabel.value'].unique():
        df1 = df.drop([ind], axis=0)
        r = [random.randint(0,len(df1)-1) for _ in range(3)]
        
        question_1 = "Quel est le pays organisateur ?"
        r_answer_1 = val['countryLabel.value']
        answers_1 = df1.reset_index().loc[r,'countryLabel.value']
        
        question_2 = "Quel est le pays vainqueur ?"
        r_answer_2 = val['winnerLabel.value']
        answers_2 = df1.reset_index().loc[r,'winnerLabel.value']
        
        question_3 = "Quel est le nombre de pays participants ?"
        r_answer_3 = val['participantsLabel.value']
        answers_3 = df1.reset_index().loc[r,'participantsLabel.value']

        question_4 = "Qui est le meilleur buteur ?"
        r_answer_4 = val['leaderLabel.value']
        answers_4 = df1.reset_index().loc[r,'leaderLabel.value']
        
        questions = [question_1, question_2, question_3, question_4]
        answers = [r_answer_1,r_answer_2,r_answer_3, r_answer_4]
        alt_answers = [answers_1,answers_2,answers_3, answers_4]
        
        quiz_bank[val['itemLabel.value']] = {"Question": questions, "R_Answers": answers, "Answers": alt_answers}
    return quiz_bank

# %%
quiz = quiz_bank(results_df)
quiz['2006 FIFA World Cup']
# Out:
# {'Question': ['Quel est le pays organisateur ?',
#   'Quel est le pays vainqueur ?',
#   'Quel est le nombre de pays participants ?',
#   'Qui est le meilleur buteur ?'],
#  'R_Answers': ['Germany', 'Italy', '32', 'Miroslav Klose'],
#  'Answers': [1      Italy
#   18    Brazil
#   2     France
#   Name: countryLabel.value, dtype: object,
#   1       Italy
#   18    Germany
#   2       Italy
#   Name: winnerLabel.value, dtype: object,
#   1     16
#   18    32
#   2     15
#   Name: participantsLabel.value, dtype: object,
#   1     Oldřich Nejedlý
#   18      Thomas Müller
#   2            Leônidas
#   Name: leaderLabel.value, dtype: object]}
