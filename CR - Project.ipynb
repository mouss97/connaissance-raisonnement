# %%
! pip install sparqlwrapper
# Out:
# Collecting sparqlwrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Collecting rdflib>=6.1.1
#   Downloading rdflib-6.2.0-py3-none-any.whl (500 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.3/500.3 kB 6.7 MB/s eta 0:00:009.9 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/moustaphalo/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=6.1.1->sparqlwrapper) (65.5.0)
# Requirement already satisfied: isodate in /Users/moustaphalo/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=6.1.1->sparqlwrapper) (0.6.1)
# Requirement already satisfied: pyparsing in /Users/moustaphalo/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=6.1.1->sparqlwrapper) (3.0.9)
# Requirement already satisfied: six in /Users/moustaphalo/opt/anaconda3/lib/python3.9/site-packages (from isodate->rdflib>=6.1.1->sparqlwrapper) (1.16.0)
# Installing collected packages: rdflib, sparqlwrapper
# Successfully installed rdflib-6.2.0 sparqlwrapper-2.0.0

# %%
import pandas as pd
import numpy as np
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

# %%
sparql.setQuery("""
SELECT ?item ?itemLabel ?country ?countryLabel ?participants ?participantsLabel ?winner ?winnerLabel

WHERE {
  # ?item wdt:P3450 wd:Q19317;
      wdt:P17 ?country.
  # ?item wdt:P3450 wd:Q19317;
      wdt:P1132 ?participants.
  # ?item wdt:P3450 wd:Q19317;
      wdt:P1346 ?winner.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")

# %%
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results
# Out:
# {'head': {'vars': ['item',
#    'itemLabel',
#    'country',
#    'countryLabel',
#    'participants',
#    'participantsLabel',
#    'winner',
#    'winnerLabel']},
#  'results': {'bindings': [{'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q37285'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q676899'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q183'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2006 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Germany'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Italy national association football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q46934'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q676899'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '24'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q96'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1982 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mexico'},
#     'participantsLabel': {'type': 'literal', 'value': '24'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Italy national association football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q46938'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q79800'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '24'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q96'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1986 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mexico'},
#     'participantsLabel': {'type': 'literal', 'value': '24'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Argentina national football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q46943'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q79800'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q414'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1978 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Argentina'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Argentina national football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q47735'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '33'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q17'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2002 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Japan'},
#     'participantsLabel': {'type': 'literal', 'value': '33'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q47735'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '33'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q884'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2002 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South Korea'},
#     'participantsLabel': {'type': 'literal', 'value': '33'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q48432'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q134916'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '13'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q77'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1930 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Uruguay'},
#     'participantsLabel': {'type': 'literal', 'value': '13'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Uruguay national football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q79859'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43310'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q155'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2014 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Brazil'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Germany national association football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q101730'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q47774'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q142'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1998 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'France'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'France national association football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q101751'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '24'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1994 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'United States of America'},
#     'participantsLabel': {'type': 'literal', 'value': '24'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q131075'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43310'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q39'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1954 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Switzerland'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Germany national association football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q131591'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q676899'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '15'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q142'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1938 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'France'},
#     'participantsLabel': {'type': 'literal', 'value': '15'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Italy national association football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q132515'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q134916'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '13'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q155'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1950 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Brazil'},
#     'participantsLabel': {'type': 'literal', 'value': '13'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Uruguay national football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q132529'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43310'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '24'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q38'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1990 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italy'},
#     'participantsLabel': {'type': 'literal', 'value': '24'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Germany national association football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q132533'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q34'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1958 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sweden'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q132664'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q96'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1970 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mexico'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q134202'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q47762'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q145'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1966 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'United Kingdom'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'England national association football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q160813'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q83459'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q298'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1962 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chile'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Brazil national football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q166121'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43310'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q183'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1974 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Germany'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Germany national association football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q170645'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q47774'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q159'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2018 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Russia'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'France national association football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q176883'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q42267'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q258'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2010 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South Africa'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Spain national association football team'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q284163'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q79800'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '32'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q846'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '2022 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qatar'},
#     'participantsLabel': {'type': 'literal', 'value': '32'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Argentina national football team'}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1477177'},
#     'winner': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q676899'},
#     'participants': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '16'},
#     'country': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q38'},
#     'itemLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '1934 FIFA World Cup'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italy'},
#     'participantsLabel': {'type': 'literal', 'value': '16'},
#     'winnerLabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Italy national association football team'}}]}}

# %%
results_df = pd.io.json.json_normalize(results['results']['bindings'])
results_df[['item.value', 'itemLabel.value', 'winnerLabel.value',\
            'participantsLabel.value', 'countryLabel.value']].sort_values(by = "itemLabel.value")
# Out:
# /var/folders/sp/bydmsjh57wn_6dyrztjzn25c0000gn/T/ipykernel_57228/2677568222.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   results_df = pd.io.json.json_normalize(results['results']['bindings'])
#                                  item.value      itemLabel.value  \
# 6     http://www.wikidata.org/entity/Q48432  1930 FIFA World Cup
# 22  http://www.wikidata.org/entity/Q1477177  1934 FIFA World Cup
# 11   http://www.wikidata.org/entity/Q131591  1938 FIFA World Cup
# 12   http://www.wikidata.org/entity/Q132515  1950 FIFA World Cup
# 10   http://www.wikidata.org/entity/Q131075  1954 FIFA World Cup
# 14   http://www.wikidata.org/entity/Q132533  1958 FIFA World Cup
# 17   http://www.wikidata.org/entity/Q160813  1962 FIFA World Cup
# 16   http://www.wikidata.org/entity/Q134202  1966 FIFA World Cup
# 15   http://www.wikidata.org/entity/Q132664  1970 FIFA World Cup
# 18   http://www.wikidata.org/entity/Q166121  1974 FIFA World Cup
# 3     http://www.wikidata.org/entity/Q46943  1978 FIFA World Cup
# 1     http://www.wikidata.org/entity/Q46934  1982 FIFA World Cup
# 2     http://www.wikidata.org/entity/Q46938  1986 FIFA World Cup
# 13   http://www.wikidata.org/entity/Q132529  1990 FIFA World Cup
# 9    http://www.wikidata.org/entity/Q101751  1994 FIFA World Cup
# 8    http://www.wikidata.org/entity/Q101730  1998 FIFA World Cup
# 5     http://www.wikidata.org/entity/Q47735  2002 FIFA World Cup
# 4     http://www.wikidata.org/entity/Q47735  2002 FIFA World Cup
# 0     http://www.wikidata.org/entity/Q37285  2006 FIFA World Cup
# 20   http://www.wikidata.org/entity/Q176883  2010 FIFA World Cup
# 7     http://www.wikidata.org/entity/Q79859  2014 FIFA World Cup
# 19   http://www.wikidata.org/entity/Q170645  2018 FIFA World Cup
# 21   http://www.wikidata.org/entity/Q284163  2022 FIFA World Cup
#
#                              winnerLabel.value participantsLabel.value  \
# 6               Uruguay national football team                      13
# 22    Italy national association football team                      16
# 11    Italy national association football team                      15
# 12              Uruguay national football team                      13
# 10  Germany national association football team                      16
# 14               Brazil national football team                      16
# 17               Brazil national football team                      16
# 16  England national association football team                      16
# 15               Brazil national football team                      16
# 18  Germany national association football team                      16
# 3             Argentina national football team                      16
# 1     Italy national association football team                      24
# 2             Argentina national football team                      24
# 13  Germany national association football team                      24
# 9                Brazil national football team                      24
# 8    France national association football team                      32
# 5                Brazil national football team                      33
# 4                Brazil national football team                      33
# 0     Italy national association football team                      32
# 20    Spain national association football team                      32
# 7   Germany national association football team                      32
# 19   France national association football team                      32
# 21            Argentina national football team                      32
#
#           countryLabel.value
# 6                    Uruguay
# 22                     Italy
# 11                    France
# 12                    Brazil
# 10               Switzerland
# 14                    Sweden
# 17                     Chile
# 16            United Kingdom
# 15                    Mexico
# 18                   Germany
# 3                  Argentina
# 1                     Mexico
# 2                     Mexico
# 13                     Italy
# 9   United States of America
# 8                     France
# 5                South Korea
# 4                      Japan
# 0                    Germany
# 20              South Africa
# 7                     Brazil
# 19                    Russia
# 21                     Qatar

# %%
sparql.setQuery("""
SELECT ?country ?countryLabel

WHERE {
   wd:Q284163 wdt:P17 ?country.
  
  
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")

# %%
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['country', 'countryLabel']},
#  'results': {'bindings': [{'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q846'},
#     'countryLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Qatar'}}]}}

# %%
results_df = pd.io.json.json_normalize(results['results']['bindings'])
results_df[['country.value', 'countryLabel.value']]
# Out:
# /var/folders/sp/bydmsjh57wn_6dyrztjzn25c0000gn/T/ipykernel_57228/1254446174.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   results_df = pd.io.json.json_normalize(results['results']['bindings'])
#                          country.value countryLabel.value
# 0  http://www.wikidata.org/entity/Q846              Qatar
